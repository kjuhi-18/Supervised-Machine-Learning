# %%
import pandas as pd

# %%
df=pd.read_csv("Iris.csv")

# %%
df.head(
    
)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.drop(["Id"],inplace=True,axis=1)

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
X=df["PetalLengthCm"]

# %%
y=df["PetalWidthCm"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=42)

# %%
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)

# %%
from sklearn import neighbors
model=neighbors.KNeighborsRegressor(n_neighbors=3)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.940145563341167

# %%
from sklearn.metrics import root_mean_squared_error
error=root_mean_squared_error(y_test,y_pred)

# %%
error
# Out:
# 0.19593828841116548

# %%
rmse_val=[]
k_list=[]
for k in range(50):
    k=k+1
    model=neighbors.KNeighborsRegressor(n_neighbors=k)
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    error=root_mean_squared_error(y_test,y_pred)
    rmse_val.append(error)
    k_list.append(k)
    print("RMSE value for k=",k,"is",error)
# Out:
# RMSE value for k= 1 is 0.33245498310218435
# RMSE value for k= 2 is 0.22168612234893112
# RMSE value for k= 3 is 0.19593828841116548
# RMSE value for k= 4 is 0.19330913339165218
# RMSE value for k= 5 is 0.19128375175171183
# RMSE value for k= 6 is 0.18155034099607043
# RMSE value for k= 7 is 0.187870650476382
# RMSE value for k= 8 is 0.18064212949190012
# RMSE value for k= 9 is 0.16847942052280782
# RMSE value for k= 10 is 0.16241597017664564
# RMSE value for k= 11 is 0.16906852761274963
# RMSE value for k= 12 is 0.16564930721997034
# RMSE value for k= 13 is 0.1703907612603748
# RMSE value for k= 14 is 0.1658352876872714
# RMSE value for k= 15 is 0.1679146260378377
# RMSE value for k= 16 is 0.16522885842943635
# RMSE value for k= 17 is 0.16703353054943526
# RMSE value for k= 18 is 0.16846254666729224
# RMSE value for k= 19 is 0.16676164859258852
# RMSE value for k= 20 is 0.16553342801221052
# RMSE value for k= 21 is 0.16417216663723774
# RMSE value for k= 22 is 0.16384721927993692
# RMSE value for k= 23 is 0.16380371955922943
# RMSE value for k= 24 is 0.169206254550319
# RMSE value for k= 25 is 0.1695008150888646
# RMSE value for k= 26 is 0.1700065032555364
# RMSE value for k= 27 is 0.17193639951535808
# RMSE value for k= 28 is 0.17428020606358
# RMSE value for k= 29 is 0.17642609101927065
# RMSE value for k= 30 is 0.17614288458372
# RMSE value for k= 31 is 0.17706245937201767
# RMSE value for k= 32 is 0.17968499712215674
# RMSE value for k= 33 is 0.18241528747089228
# RMSE value for k= 34 is 0.1804176744190016
# RMSE value for k= 35 is 0.18009783711771507
# RMSE value for k= 36 is 0.18239893460497306
# RMSE value for k= 37 is 0.188563790539259
# RMSE value for k= 38 is 0.19417640400192357
# RMSE value for k= 39 is 0.19725090795557115
# RMSE value for k= 40 is 0.2005371077355694
# RMSE value for k= 41 is 0.20439609551643248
# RMSE value for k= 42 is 0.21034066957892747
# RMSE value for k= 43 is 0.22013643389704052
# RMSE value for k= 44 is 0.22765906159289778
# RMSE value for k= 45 is 0.23534581857553288
# RMSE value for k= 46 is 0.2468488601658867
# RMSE value for k= 47 is 0.25393029307922077
# RMSE value for k= 48 is 0.26110588620036806
# RMSE value for k= 49 is 0.26790780043713197
# RMSE value for k= 50 is 0.2773804152005727

# %%
best_rmse=min(rmse_val)
best_k=k_list[rmse_val.index(best_rmse)]
print(best_k)
print(best_rmse)
# Out:
# 10
# 0.16241597017664564

# %%
import matplotlib.pyplot as plt
plt.plot(k_list,rmse_val)

# %%
X=df["SepalLengthCm"]
y=df["SepalWidthCm"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=42)

# %%
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)

# %%
from sklearn import neighbors
model=neighbors.KNeighborsRegressor(n_neighbors=15)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.05642415010092605

# %%
from sklearn.metrics import root_mean_squared_error
error=root_mean_squared_error(y_test,y_pred)
error
# Out:
# 0.415948152414548

# %%
rmse_val=[]
k_list=[]
for k in range(50):
    k=k+1
    model=neighbors.KNeighborsRegressor(n_neighbors=k)
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    error=root_mean_squared_error(y_test,y_pred)
    rmse_val.append(error)
    k_list.append(k)
    print("RMSE value for k=",k,"is",error)
# Out:
# RMSE value for k= 1 is 0.5293988646519152
# RMSE value for k= 2 is 0.440767870641082
# RMSE value for k= 3 is 0.44254711976960626
# RMSE value for k= 4 is 0.4637873264876115
# RMSE value for k= 5 is 0.4617700498596335
# RMSE value for k= 6 is 0.45864821719320237
# RMSE value for k= 7 is 0.4491249398557485
# RMSE value for k= 8 is 0.44233698305584557
# RMSE value for k= 9 is 0.4391719421841739
# RMSE value for k= 10 is 0.41301522846908245
# RMSE value for k= 11 is 0.41921289571722886
# RMSE value for k= 12 is 0.4171028418768618
# RMSE value for k= 13 is 0.4210274245023958
# RMSE value for k= 14 is 0.4172470000806022
# RMSE value for k= 15 is 0.415948152414548
# RMSE value for k= 16 is 0.4219706275634784
# RMSE value for k= 17 is 0.4206970133639649
# RMSE value for k= 18 is 0.4304786764036131
# RMSE value for k= 19 is 0.43256087202159454
# RMSE value for k= 20 is 0.42791876996015327
# RMSE value for k= 21 is 0.42783074396629633
# RMSE value for k= 22 is 0.42696084514670224
# RMSE value for k= 23 is 0.42458053415938174
# RMSE value for k= 24 is 0.4214034482868764
# RMSE value for k= 25 is 0.42296497304274816
# RMSE value for k= 26 is 0.41445718553569244
# RMSE value for k= 27 is 0.40854793395428496
# RMSE value for k= 28 is 0.4040730630458673
# RMSE value for k= 29 is 0.402874318339784
# RMSE value for k= 30 is 0.4038817498182571
# RMSE value for k= 31 is 0.40889495213004307
# RMSE value for k= 32 is 0.4032709599081779
# RMSE value for k= 33 is 0.40541529098615137
# RMSE value for k= 34 is 0.40952481224565257
# RMSE value for k= 35 is 0.40916566492483636
# RMSE value for k= 36 is 0.40983160894848925
# RMSE value for k= 37 is 0.410002620834025
# RMSE value for k= 38 is 0.4117346730922581
# RMSE value for k= 39 is 0.4107480606667544
# RMSE value for k= 40 is 0.40804532449484743
# RMSE value for k= 41 is 0.41292709086034296
# RMSE value for k= 42 is 0.40893634643281906
# RMSE value for k= 43 is 0.40892034584983683
# RMSE value for k= 44 is 0.40975341755913636
# RMSE value for k= 45 is 0.4097137624262914
# RMSE value for k= 46 is 0.41153751113638604
# RMSE value for k= 47 is 0.4146703105947736
# RMSE value for k= 48 is 0.41424832735671524
# RMSE value for k= 49 is 0.41290571936038223
# RMSE value for k= 50 is 0.41468288454774943

# %%
best_rmse=min(rmse_val)
best_k=k_list[rmse_val.index(best_rmse)]
print(best_k)
print(best_rmse)
# Out:
# 29
# 0.402874318339784

# %%
import matplotlib.pyplot as plt
plt.plot(k_list,rmse_val)
